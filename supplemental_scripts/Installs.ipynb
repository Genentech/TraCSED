# %%
pip install typing
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting typing
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: typing
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26306 sha256=ea55f88593d9af33b0fe018e4a81dab1615298837bceb9ef8d482a3f9b0b4963
#   Stored in directory: /gstore/home/mauldinn/.cache/pip/wheels/e5/23/95/593222493ec6253200e94e4a5ee4361d12112000816d840434
# Successfully built typing
# Installing collected packages: typing
# Successfully installed typing-3.7.4.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install multiprocessing
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting multiprocessing
#   Downloading multiprocessing-2.6.2.1.tar.gz (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 1.0 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [7 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/local/13043257/pip-install-oa4s4q0q/multiprocessing_617d990700404ca0918ddf8e702e4eb1/setup.py", line 94
#           print 'Macros:'
#           ^^^^^^^^^^^^^^^
#       SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cython
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting cython
#   Downloading Cython-0.29.35-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 5.9 MB/s eta 0:00:0000:0100:01
# Installing collected packages: cython
#   WARNING: The scripts cygdb, cython and cythonize are installed in '/gstore/home/mauldinn/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed cython-0.29.35
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pdpbox
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pdpbox
#   Downloading PDPbox-0.3.0-py3-none-any.whl (35.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.8/35.8 MB 8.4 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: joblib>=1.1.0 in ./.local/lib/python3.10/site-packages (from pdpbox) (1.2.0)
# Requirement already satisfied: psutil>=5.9.0 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from pdpbox) (5.9.0)
# Collecting pytest
#   Downloading pytest-7.4.0-py3-none-any.whl (323 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.6/323.6 kB 1.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.21.5 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from pdpbox) (1.23.5)
# Collecting plotly>=5.9.0
#   Downloading plotly-5.15.0-py2.py3-none-any.whl (15.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 3.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pandas>=1.4.4 in ./.local/lib/python3.10/site-packages (from pdpbox) (1.5.3)
# Collecting sphinx>=5.0.2
#   Downloading sphinx-7.0.1-py3-none-any.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 3.6 MB/s eta 0:00:0000:0100:01
# Collecting xgboost>=1.7.1
#   Downloading xgboost-1.7.6-py3-none-manylinux2014_x86_64.whl (200.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.3/200.3 MB 10.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: scikit-learn>=1.0.2 in ./.local/lib/python3.10/site-packages (from pdpbox) (1.2.2)
# Requirement already satisfied: matplotlib>=3.6.2 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from pdpbox) (3.6.2)
# Collecting sphinx-rtd-theme>=1.1.1
#   Downloading sphinx_rtd_theme-1.2.2-py2.py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 25.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tqdm>=4.64.1 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from pdpbox) (4.64.1)
# Collecting pqdm>=0.2.0
#   Downloading pqdm-0.2.0-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: setuptools in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from pdpbox) (65.6.3)
# Collecting numpydoc>=1.4.0
#   Downloading numpydoc-1.5.0-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.4/52.4 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: fonttools>=4.22.0 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from matplotlib>=3.6.2->pdpbox) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from matplotlib>=3.6.2->pdpbox) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from matplotlib>=3.6.2->pdpbox) (9.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from matplotlib>=3.6.2->pdpbox) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from matplotlib>=3.6.2->pdpbox) (22.0)
# Requirement already satisfied: cycler>=0.10 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from matplotlib>=3.6.2->pdpbox) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from matplotlib>=3.6.2->pdpbox) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from matplotlib>=3.6.2->pdpbox) (1.4.4)
# Requirement already satisfied: Jinja2>=2.10 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from numpydoc>=1.4.0->pdpbox) (3.1.2)
# Requirement already satisfied: pytz>=2020.1 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from pandas>=1.4.4->pdpbox) (2022.7)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.2.2-py3-none-any.whl (24 kB)
# Collecting bounded-pool-executor
#   Downloading bounded_pool_executor-0.0.3-py3-none-any.whl (3.4 kB)
# Requirement already satisfied: typing-extensions in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from pqdm>=0.2.0->pdpbox) (4.4.0)
# Requirement already satisfied: scipy>=1.3.2 in ./.local/lib/python3.10/site-packages (from scikit-learn>=1.0.2->pdpbox) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.local/lib/python3.10/site-packages (from scikit-learn>=1.0.2->pdpbox) (3.1.0)
# Collecting Pygments>=2.13
#   Downloading Pygments-2.15.1-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 25.1 MB/s eta 0:00:0000:01
# Requirement already satisfied: requests>=2.25.0 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from sphinx>=5.0.2->pdpbox) (2.28.1)
# Collecting alabaster<0.8,>=0.7
#   Downloading alabaster-0.7.13-py3-none-any.whl (13 kB)
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Collecting sphinxcontrib-htmlhelp>=2.0.0
#   Downloading sphinxcontrib_htmlhelp-2.0.1-py3-none-any.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.8/99.8 kB 3.6 MB/s eta 0:00:00
# Collecting docutils<0.21,>=0.18.1
#   Downloading docutils-0.20.1-py3-none-any.whl (572 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.7/572.7 kB 10.1 MB/s eta 0:00:0000:01
# Collecting imagesize>=1.3
#   Downloading imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 7.7 MB/s eta 0:00:00
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.7/84.7 kB 9.2 MB/s eta 0:00:00
# Collecting snowballstemmer>=2.0
#   Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.0/93.0 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: babel>=2.9 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from sphinx>=5.0.2->pdpbox) (2.11.0)
# Collecting sphinxcontrib-serializinghtml>=1.1.5
#   Downloading sphinxcontrib_serializinghtml-1.1.5-py2.py3-none-any.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 11.5 MB/s eta 0:00:00
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-1.0.4-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.6/120.6 kB 9.0 MB/s eta 0:00:00
# Collecting docutils<0.21,>=0.18.1
#   Downloading docutils-0.18.1-py2.py3-none-any.whl (570 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.0/570.0 kB 7.4 MB/s eta 0:00:0000:01
# Collecting sphinx>=5.0.2
#   Downloading sphinx-6.2.1-py3-none-any.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 26.5 MB/s eta 0:00:0000:0100:01
# Collecting sphinxcontrib-jquery<5,>=4
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: tomli>=1.0.0 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from pytest->pdpbox) (2.0.1)
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.2.0-py3-none-any.whl (17 kB)
# Collecting iniconfig
#   Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Collecting exceptiongroup>=1.0.0rc8
#   Downloading exceptiongroup-1.1.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from Jinja2>=2.10->numpydoc>=1.4.0->pdpbox) (2.1.1)
# Requirement already satisfied: six>=1.5 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.6.2->pdpbox) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from requests>=2.25.0->sphinx>=5.0.2->pdpbox) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from requests>=2.25.0->sphinx>=5.0.2->pdpbox) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from requests>=2.25.0->sphinx>=5.0.2->pdpbox) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from requests>=2.25.0->sphinx>=5.0.2->pdpbox) (2023.5.7)
# Installing collected packages: snowballstemmer, bounded-pool-executor, tenacity, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, Pygments, pqdm, pluggy, iniconfig, imagesize, exceptiongroup, docutils, alabaster, xgboost, sphinx, pytest, plotly, sphinxcontrib-jquery, numpydoc, sphinx-rtd-theme, pdpbox
#   WARNING: The script pygmentize is installed in '/gstore/home/mauldinn/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts sphinx-apidoc, sphinx-autogen, sphinx-build and sphinx-quickstart are installed in '/gstore/home/mauldinn/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts py.test and pytest are installed in '/gstore/home/mauldinn/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed Pygments-2.15.1 alabaster-0.7.13 bounded-pool-executor-0.0.3 docutils-0.18.1 exceptiongroup-1.1.1 imagesize-1.4.1 iniconfig-2.0.0 numpydoc-1.5.0 pdpbox-0.3.0 plotly-5.15.0 pluggy-1.2.0 pqdm-0.2.0 pytest-7.4.0 snowballstemmer-2.2.0 sphinx-6.2.1 sphinx-rtd-theme-1.2.2 sphinxcontrib-applehelp-1.0.4 sphinxcontrib-devhelp-1.0.2 sphinxcontrib-htmlhelp-2.0.1 sphinxcontrib-jquery-4.1 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.3 sphinxcontrib-serializinghtml-1.1.5 tenacity-8.2.2 xgboost-1.7.6
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torchvision Flask-Compress
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torchvision
#   Downloading torchvision-0.15.2-cp310-cp310-manylinux1_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 886.7 kB/s eta 0:00:0000:0100:02
# Collecting Flask-Compress
#   Downloading Flask_Compress-1.13-py3-none-any.whl (7.9 kB)
# Collecting torch==2.0.1
#   Downloading torch-2.0.1-cp310-cp310-manylinux1_x86_64.whl (619.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 3.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from torchvision) (1.23.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from torchvision) (9.3.0)
# Requirement already satisfied: requests in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from torchvision) (2.28.1)
# Requirement already satisfied: networkx in ./.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (3.0)
# Requirement already satisfied: jinja2 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in ./.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in ./.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (8.5.0.96)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in ./.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (10.2.10.91)
# Requirement already satisfied: filelock in ./.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (3.10.2)
# Requirement already satisfied: typing-extensions in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (4.4.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in ./.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in ./.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in ./.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (10.9.0.58)
# Requirement already satisfied: triton==2.0.0 in ./.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (2.0.0)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in ./.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (11.7.101)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in ./.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (11.7.4.91)
# Requirement already satisfied: sympy in ./.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (1.11.1)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in ./.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (11.7.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in ./.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (2.14.3)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in ./.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (11.4.0.1)
# Requirement already satisfied: setuptools in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchvision) (65.6.3)
# Requirement already satisfied: wheel in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchvision) (0.37.1)
# Requirement already satisfied: cmake in ./.local/lib/python3.10/site-packages (from triton==2.0.0->torch==2.0.1->torchvision) (3.26.0)
# Requirement already satisfied: lit in ./.local/lib/python3.10/site-packages (from triton==2.0.0->torch==2.0.1->torchvision) (16.0.0)
# Collecting flask
#   Downloading Flask-2.3.2-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 10.3 MB/s eta 0:00:00
# Collecting brotli
#   Downloading Brotli-1.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 13.4 MB/s eta 0:00:0000:0100:01
# Collecting itsdangerous>=2.1.2
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting click>=8.1.3
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 11.7 MB/s eta 0:00:00
# Collecting Werkzeug>=2.3.3
#   Downloading Werkzeug-2.3.6-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 14.8 MB/s eta 0:00:00
# Collecting blinker>=1.6.2
#   Downloading blinker-1.6.2-py3-none-any.whl (13 kB)
# Requirement already satisfied: idna<4,>=2.5 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from requests->torchvision) (2023.5.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from requests->torchvision) (1.26.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from jinja2->torch==2.0.1->torchvision) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in ./.local/lib/python3.10/site-packages (from sympy->torch==2.0.1->torchvision) (1.3.0)
# Installing collected packages: brotli, Werkzeug, itsdangerous, click, blinker, flask, Flask-Compress, torch, torchvision
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 2.2.3
#     Uninstalling Werkzeug-2.2.3:
#       Successfully uninstalled Werkzeug-2.2.3
#   WARNING: The script flask is installed in '/gstore/home/mauldinn/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.0
#     Uninstalling torch-2.0.0:
#       Successfully uninstalled torch-2.0.0
#   WARNING: The scripts convert-caffe2-to-onnx, convert-onnx-to-caffe2 and torchrun are installed in '/gstore/home/mauldinn/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed Flask-Compress-1.13 Werkzeug-2.3.6 blinker-1.6.2 brotli-1.0.9 click-8.1.3 flask-2.3.2 itsdangerous-2.1.2 torch-2.0.1 torchvision-0.15.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install shap
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting shap
#   Downloading shap-0.41.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (572 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.6/572.6 kB 2.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pandas in ./.local/lib/python3.10/site-packages (from shap) (1.5.3)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Collecting cloudpickle
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Requirement already satisfied: tqdm>4.25.0 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from shap) (4.64.1)
# Requirement already satisfied: scikit-learn in ./.local/lib/python3.10/site-packages (from shap) (1.2.2)
# Requirement already satisfied: scipy in ./.local/lib/python3.10/site-packages (from shap) (1.10.1)
# Requirement already satisfied: numpy in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from shap) (1.23.5)
# Requirement already satisfied: packaging>20.9 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from shap) (22.0)
# Collecting numba
#   Downloading numba-0.57.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 18.2 MB/s eta 0:00:0000:0100:01
# Collecting llvmlite<0.41,>=0.40.0dev0
#   Downloading llvmlite-0.40.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 4.1 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: pytz>=2020.1 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from pandas->shap) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.local/lib/python3.10/site-packages (from scikit-learn->shap) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in ./.local/lib/python3.10/site-packages (from scikit-learn->shap) (1.2.0)
# Requirement already satisfied: six>=1.5 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# Installing collected packages: slicer, llvmlite, cloudpickle, numba, shap
# Successfully installed cloudpickle-2.2.1 llvmlite-0.40.0 numba-0.57.0 shap-0.41.0 slicer-0.0.7
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install eli5
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting eli5
#   Downloading eli5-0.13.0.tar.gz (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.2/216.2 kB 1.5 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: attrs>17.1.0 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from eli5) (22.1.0)
# Requirement already satisfied: jinja2>=3.0.0 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from eli5) (3.1.2)
# Requirement already satisfied: numpy>=1.9.0 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from eli5) (1.23.5)
# Requirement already satisfied: scipy in ./.local/lib/python3.10/site-packages (from eli5) (1.10.1)
# Requirement already satisfied: six in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from eli5) (1.16.0)
# Requirement already satisfied: scikit-learn>=0.20 in ./.local/lib/python3.10/site-packages (from eli5) (1.2.2)
# Requirement already satisfied: graphviz in ./.local/lib/python3.10/site-packages (from eli5) (0.20.1)
# Collecting tabulate>=0.7.7
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from jinja2>=3.0.0->eli5) (2.1.1)
# Requirement already satisfied: joblib>=1.1.1 in ./.local/lib/python3.10/site-packages (from scikit-learn>=0.20->eli5) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.local/lib/python3.10/site-packages (from scikit-learn>=0.20->eli5) (3.1.0)
# Building wheels for collected packages: eli5
#   Building wheel for eli5 (setup.py) ... done
#   Created wheel for eli5: filename=eli5-0.13.0-py2.py3-none-any.whl size=107728 sha256=eea11ee906bd96ccb6c4f30d0c08305b2767c58cbee0333b9e6b77e8cfb054f2
#   Stored in directory: /gstore/home/mauldinn/.cache/pip/wheels/79/6c/4b/13ea3238d017bc19711b4312359e2c95be91a1a9d60d949572
# Successfully built eli5
# Installing collected packages: tabulate, eli5
#   WARNING: The script tabulate is installed in '/gstore/home/mauldinn/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed eli5-0.13.0 tabulate-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow
#   Downloading tensorflow-2.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (585.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.9/585.9 MB 4.9 MB/s eta 0:00:0000:0100:01
# Collecting tensorflow-estimator<2.13,>=2.12.0
#   Downloading tensorflow_estimator-2.12.0-py2.py3-none-any.whl (440 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 7.9 MB/s eta 0:00:0000:01
# Collecting jax>=0.3.15
#   Downloading jax-0.4.8.tar.gz (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 13.6 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 5.4 MB/s eta 0:00:00
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.32.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 13.9 MB/s eta 0:00:0000:0100:01
# Collecting wrapt<1.15,>=1.11.0
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 8.9 MB/s eta 0:00:00
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.2.0-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: packaging in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from tensorflow) (22.0)
# Collecting h5py>=2.9.0
#   Downloading h5py-3.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 15.5 MB/s eta 0:00:0000:0100:01
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting keras<2.13,>=2.12.0
#   Downloading keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 12.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy<1.24,>=1.22 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: six>=1.12.0 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Collecting libclang>=13.0.0
#   Downloading libclang-16.0.0-py2.py3-none-manylinux2010_x86_64.whl (22.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.9/22.9 MB 15.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions>=3.6.6 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from tensorflow) (4.4.0)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.4 MB/s eta 0:00:00
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Downloading protobuf-4.22.3-cp37-abi3-manylinux2014_x86_64.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.4/302.4 kB 14.7 MB/s eta 0:00:00
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-23.3.3-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: setuptools in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from tensorflow) (65.6.3)
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.5/126.5 kB 13.1 MB/s eta 0:00:00
# Collecting tensorboard<2.13,>=2.12
#   Downloading tensorboard-2.12.2-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 17.6 MB/s eta 0:00:0000:0100:01
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.53.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 17.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: scipy>=1.7 in ./.local/lib/python3.10/site-packages (from jax>=0.3.15->tensorflow) (1.10.1)
# Collecting ml-dtypes>=0.0.3
#   Downloading ml_dtypes-0.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 13.4 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 16.1 MB/s eta 0:00:0000:01
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.0-py3-none-manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 18.7 MB/s eta 0:00:0000:0100:01
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.17.3-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.2/178.2 kB 18.7 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.21.0 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.28.1)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.2.3-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 17.3 MB/s eta 0:00:00
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.3-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 kB 6.9 MB/s eta 0:00:00
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 10.2 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.1)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 6.7 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 12.5 MB/s eta 0:00:00
# Building wheels for collected packages: jax
#   Building wheel for jax (pyproject.toml) ... done
#   Created wheel for jax: filename=jax-0.4.8-py3-none-any.whl size=1439678 sha256=9f58332aae72c1690bec761eaa1879b56050e0770e714c82723a46c4dffb7b1d
#   Stored in directory: /gstore/home/mauldinn/.cache/pip/wheels/d6/f6/d5/63686989c723075de411cbc630ca12f4241a8436e411e38d6a
# Successfully built jax
# Installing collected packages: tensorboard-plugin-wit, pyasn1, libclang, flatbuffers, wrapt, werkzeug, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, rsa, pyasn1-modules, protobuf, opt-einsum, oauthlib, ml-dtypes, markdown, keras, h5py, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, requests-oauthlib, jax, google-auth, google-auth-oauthlib, tensorboard, tensorflow
#   WARNING: The scripts pyrsa-decrypt, pyrsa-encrypt, pyrsa-keygen, pyrsa-priv2pub, pyrsa-sign and pyrsa-verify are installed in '/gstore/home/mauldinn/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown_py is installed in '/gstore/home/mauldinn/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script google-oauthlib-tool is installed in '/gstore/home/mauldinn/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tensorboard is installed in '/gstore/home/mauldinn/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts estimator_ckpt_converter, import_pb_to_tensorboard, saved_model_cli, tensorboard, tf_upgrade_v2, tflite_convert, toco and toco_from_protos are installed in '/gstore/home/mauldinn/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed absl-py-1.4.0 astunparse-1.6.3 cachetools-5.3.0 flatbuffers-23.3.3 gast-0.4.0 google-auth-2.17.3 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 grpcio-1.53.0 h5py-3.8.0 jax-0.4.8 keras-2.12.0 libclang-16.0.0 markdown-3.4.3 ml-dtypes-0.1.0 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-4.22.3 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.12.2 tensorboard-data-server-0.7.0 tensorboard-plugin-wit-1.8.1 tensorflow-2.12.0 tensorflow-estimator-2.12.0 tensorflow-io-gcs-filesystem-0.32.0 termcolor-2.2.0 werkzeug-2.2.3 wrapt-1.14.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install kaggle
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting kaggle
#   Downloading kaggle-1.5.13.tar.gz (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 347.9 kB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.10 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from kaggle) (2022.12.7)
# Requirement already satisfied: python-dateutil in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from kaggle) (2.28.1)
# Requirement already satisfied: tqdm in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from kaggle) (4.64.1)
# Collecting python-slugify
#   Downloading python_slugify-8.0.1-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: urllib3 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from kaggle) (1.26.13)
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<3,>=2 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from requests->kaggle) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from requests->kaggle) (3.4)
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.5.13-py3-none-any.whl size=77717 sha256=25ba43519961818a15c68915569c86cd24a304b28a5705c2ffa6222ec6a97589
#   Stored in directory: /gstore/home/mauldinn/.cache/pip/wheels/1b/22/79/e73b3e988388377c1cda3385bfa20c1799be101c2e12bbe3dc
# Successfully built kaggle
# Installing collected packages: text-unidecode, python-slugify, kaggle
#   WARNING: The script slugify is installed in '/gstore/home/mauldinn/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script kaggle is installed in '/gstore/home/mauldinn/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed kaggle-1.5.13 python-slugify-8.0.1 text-unidecode-1.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pydotplus
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pydotplus
#   Downloading pydotplus-2.0.2.tar.gz (278 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.7/278.7 kB 1.3 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyparsing>=2.0.1 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from pydotplus) (3.0.9)
# Building wheels for collected packages: pydotplus
#   Building wheel for pydotplus (setup.py) ... done
#   Created wheel for pydotplus: filename=pydotplus-2.0.2-py3-none-any.whl size=24554 sha256=b106df230eb977cb77c971a25942ed85e0df3d86a0841c8356aaaa5b20e428af
#   Stored in directory: /gstore/home/mauldinn/.cache/pip/wheels/5c/94/1f/953aa60af58ef512e5256e538ff0772c340229e5996ac51fd6
# Successfully built pydotplus
# Installing collected packages: pydotplus
# Successfully installed pydotplus-2.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pydot
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pydot in ./.local/lib/python3.10/site-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from pydot) (3.0.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install graphviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: graphviz in ./.local/lib/python3.10/site-packages (0.20.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install graphviz
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: -
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                                             \ / -failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - argon2-cffi -> python[version='>=2.7,<2.8.0a0|>=3.11,<3.12.0a0|>=3.5,<3.6.0a0']
#   - argon2-cffi-bindings -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - asttokens -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0|>=3.9,<3.10.0a0|>=3.5,<3.6.0a0']
#   - backcall -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0']
#   - brotlipy -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - contourpy -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0']
#   - defusedxml -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - ipython_genutils -> python[version='>=2.7,<2.8.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - pexpect -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.5,<3.6.0a0']
#   - ptyprocess -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.6,<3.7.0a0']
#   - pyrsistent -> python[version='>=3.5,<3.6.0a0']
#   - python-dateutil -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - python-dateutil -> python[version='>=3.8,<3.9.0a0|>=3.9,<3.10.0a0']
#   - send2trash -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0']
#   - six -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0|>=3.9,<3.10.0a0|>=3.5,<3.6.0a0']
#   - sniffio -> python[version='>=3,<3.7']
#   - soupsieve -> python[version='>=3.5,<3.6.0a0']
#   - tinycss2 -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0']
#   - wcwidth -> python[version='>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - websocket-client -> python[version='>=3.5,<3.6.0a0']
#
# Your python: python=3.10
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
# The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package zlib conflicts for:
# matplotlib-inline -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# markupsafe -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# libpng -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# typing_extensions -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# send2trash -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# krb5 -> tk[version='>=8.6.8,<8.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0']
# curl -> libcurl==7.88.1=h91b91d3_0 -> zlib[version='>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pure_eval -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# graphviz -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# contourpy -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# parso -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# openjpeg -> zlib[version='>=1.2.11,<1.3.0a0']
# comm -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# gitdb -> python[version='>=3.4'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# decorator -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pexpect -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pyopenssl -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# zstd -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# psutil -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# prompt-toolkit -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jinja2 -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pyparsing -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# bleach -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# nss -> zlib[version='>=1.2.11,<1.3.0a0']
# charset-normalizer -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# executing -> python[version='>=2.7'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# gst-plugins-base -> zlib[version='>=1.2.11,<1.3.0a0']
# json5 -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# gstreamer -> glib[version='>=2.69.1,<3.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# asttokens -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# sqlite -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0|>=1.2.13,<2.0a0']
# ipython_genutils -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# libxkbcommon -> libxml2[version='>=2.10.3,<2.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# babel -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# tinycss2 -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# requests -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# python=3.10 -> sqlite[version='>=3.41.2,<4.0a0'] -> zlib[version='>=1.2.13,<2.0a0']
# jupyterlab-git -> python[version='>=3.6,<4.0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# tqdm -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# aiohttp -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# libpq -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0']
# nss -> sqlite[version='>=3.37.0,<4.0a0'] -> zlib[version='>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0|>=1.2.13,<2.0a0']
# libclang -> libllvm10[version='>=10.0.1,<10.1.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# beautifulsoup4 -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# mistune -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# anyio -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# gst-plugins-base -> glib[version='>=2.69.1,<3.0a0'] -> zlib[version='>=1.2.13,<1.3.0a0']
# nbclassic -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pytz -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pygments -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# debugpy -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pysocks -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# websocket-client -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jupyter-vscode-proxy -> python[version='>=3'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# async-timeout -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# gettext -> libxml2[version='>=2.10.3,<2.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# smmap -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# openjpeg -> libpng[version='>=1.6.37,<1.7.0a0'] -> zlib[version='>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# cryptography -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# colorama -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# notebook -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# six -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jupyterlab_server -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# fontconfig -> zlib[version='>=1.2.13,<1.3.0a0']
# attrs -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pillow -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# dbus -> glib -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# gitpython -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pickleshare -> python[version='>=3'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# urllib3 -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# aiosignal -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# mkl-service -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# idna -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# sniffio -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# soupsieve -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# curl -> zlib[version='>=1.2.11,<1.3.0a0']
# sip -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pyqt5-sip -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# stack_data -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# toml -> python[version='>=2.7'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# libxml2 -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# tk -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0']
# lcms2 -> libtiff[version='>=4.1.0,<5.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# ipykernel -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# ptyprocess -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# cairo -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# certifi -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# nbformat -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pcre2 -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# poppler -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# notebook-shim -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# setuptools -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# libxslt -> libxml2[version='>=2.10.3,<2.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# python-fastjsonschema -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# argon2-cffi-bindings -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# matplotlib-base -> freetype[version='>=2.10'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0|>=1.2.12,<1.3.0a0']
# glib -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# packaging -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pip -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# cycler -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# qtwebkit -> zlib[version='>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# entrypoints -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jupyterlab -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# terminado -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# libnghttp2 -> zlib[version='>=1.2.11,<1.3.0a0']
# yarl -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# fontconfig -> freetype[version='>=2.10.4,<3.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0']
# widgetsnbextension -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# libclang -> zlib[version='>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# freetype -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# nest-asyncio -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# qtwebkit -> glib[version='>=2.69.1,<3.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<2.0a0']
# brotlipy -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pyrsistent -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# traitlets -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pyqt -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# libcurl -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# qt-main -> freetype[version='>=2.10.4,<3.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<2.0a0']
# ipyparallel -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# kiwisolver -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jupyter_core -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jupyter_bokeh -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# wheel -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# mkl_fft -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pyzmq -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# argon2-cffi -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# poppler -> cairo[version='>=1.16.0,<2.0a0'] -> zlib[version='>=1.2.12,<1.3.0a0']
# frozenlist -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jupyter-server-proxy -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# git -> zlib[version='>=1.2.11,<1.3.0a0']
# typing-extensions -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pycparser -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# python=3.10 -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# texlive-core -> cairo[version='>=1.14.12,<2.0a0'] -> zlib[version='>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# nbconvert -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# mkl -> intel-openmp=2023 -> zlib[version='>=1.2.12,<1.3.0a0|>=1.2.13,<1.2.14|>=1.2.13,<1.3.0a0']
# jupyterlmod -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# nbclient -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# backcall -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# webencodings -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# qt-main -> zlib[version='>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jupyterlab_widgets -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jupyter-server-mathjax -> python[version='>=3.7'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# numpy -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jsonschema -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# fonttools -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# platformdirs -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# git -> libcurl[version='>=7.80.0,<8.0a0'] -> zlib[version='>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pyyaml -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# ipython -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# libllvm10 -> zlib[version='>=1.2.11,<1.3.0a0']
# qt-webengine -> fontconfig[version='>=2.14.1,<3.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0|>=1.2.12,<1.3.0a0']
# nbdime -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# numpy-base -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# libwebp -> libpng[version='>=1.6.37,<1.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0|>=1.2.12,<1.3.0a0']
# multidict -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# ipywidgets -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# cffi -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# prometheus_client -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# matplotlib -> zlib[version='>=1.2.11,<1.3.0a0']
# jupyter_server -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jupyterlab_pygments -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# simpervisor -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# bokeh -> pillow[version='>=7.1.0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jedi -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# wcwidth -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# mkl_random -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# texlive-core -> zlib[version='>=1.2.11,<1.3.0a0']
# matplotlib -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# ply -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# flit-core -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# defusedxml -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# libtiff -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# harfbuzz -> cairo[version='>=1.16.0,<2.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# jupyter_client -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# intel-openmp -> zlib[version='>=1.2.12,<1.3.0a0|>=1.2.13,<1.2.14|>=1.2.13,<1.3.0a0']
# python-dateutil -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# munkres -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# python_abi -> python=3.10 -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# tomli -> python[version='>=3.11,<3.12.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pandocfilters -> python[version='!=3.0,!=3.1,!=3.2,!=3.3'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
# lxml -> libxml2[version='>=2.10.3,<2.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0']
#
# Package bzip2 conflicts for:
# certifi -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# pysocks -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# soupsieve -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# mkl_fft -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# argon2-cffi -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# asttokens -> python[version='>=3.5'] -> bzip2[version='>=1.0.8,<2.0a0']
# aiohttp -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# mistune -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# pip -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# cycler -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# jupyterlab -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# nbdime -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# comm -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# gitpython -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# mkl_random -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# debugpy -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# kiwisolver -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# cffi -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# cryptography -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# wheel -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# defusedxml -> python -> bzip2[version='>=1.0.8,<2.0a0']
# psutil -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# ply -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# nbclient -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# attrs -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# json5 -> python -> bzip2[version='>=1.0.8,<2.0a0']
# pyparsing -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# frozenlist -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# lxml -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# jedi -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# nbclassic -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# backcall -> python -> bzip2[version='>=1.0.8,<2.0a0']
# flit-core -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# toml -> python[version='>=2.7'] -> bzip2[version='>=1.0.8,<2.0a0']
# jupyter_client -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# webencodings -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# bokeh -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# pure_eval -> python[version='>=3.5'] -> bzip2[version='>=1.0.8,<2.0a0']
# nest-asyncio -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# wcwidth -> python -> bzip2[version='>=1.0.8,<2.0a0']
# ptyprocess -> python -> bzip2[version='>=1.0.8,<2.0a0']
# traitlets -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# jsonschema -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# fonttools -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# jupyter_bokeh -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# jupyterlab_widgets -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# async-timeout -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# decorator -> python[version='>=3.5'] -> bzip2[version='>=1.0.8,<2.0a0']
# jinja2 -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# bleach -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# argon2-cffi-bindings -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# ipyparallel -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# jupyterlab_server -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# jupyter_core -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# jupyter-server-mathjax -> python[version='>=3.7'] -> bzip2[version='>=1.0.8,<2.0a0']
# executing -> python[version='>=2.7'] -> bzip2[version='>=1.0.8,<2.0a0']
# contourpy -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# prometheus_client -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# pyqt -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# platformdirs -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# ipywidgets -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# mkl-service -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# charset-normalizer -> python[version='>=3.5'] -> bzip2[version='>=1.0.8,<2.0a0']
# markupsafe -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# python-dateutil -> python -> bzip2[version='>=1.0.8,<2.0a0']
# setuptools -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# jupyterlab-git -> python[version='>=3.6,<4.0'] -> bzip2[version='>=1.0.8,<2.0a0']
# pytz -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# typing_extensions -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# tinycss2 -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# python_abi -> python=3.10 -> bzip2[version='>=1.0.8,<2.0a0']
# jupyter-server-proxy -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# smmap -> python -> bzip2[version='>=1.0.8,<2.0a0']
# pyzmq -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# babel -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# colorama -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# requests -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# notebook-shim -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# entrypoints -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# matplotlib-base -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# munkres -> python -> bzip2[version='>=1.0.8,<2.0a0']
# pyyaml -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# six -> python -> bzip2[version='>=1.0.8,<2.0a0']
# tomli -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# pygments -> python[version='>=3.5'] -> bzip2[version='>=1.0.8,<2.0a0']
# pandocfilters -> python[version='!=3.0,!=3.1,!=3.2,!=3.3'] -> bzip2[version='>=1.0.8,<2.0a0']
# notebook -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# sniffio -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# pickleshare -> python[version='>=3'] -> bzip2[version='>=1.0.8,<2.0a0']
# jupyterlab_pygments -> python -> bzip2[version='>=1.0.8,<2.0a0']
# jupyter_server -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# pyopenssl -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# simpervisor -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# matplotlib-inline -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# jupyter-vscode-proxy -> python[version='>=3'] -> bzip2[version='>=1.0.8,<2.0a0']
# ipykernel -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# ipython -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# typing-extensions -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# brotlipy -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# numpy-base -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# python=3.10 -> bzip2[version='>=1.0.8,<2.0a0']
# packaging -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# gitdb -> python[version='>=3.4'] -> bzip2[version='>=1.0.8,<2.0a0']
# anyio -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# prompt-toolkit -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# websocket-client -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# urllib3 -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# terminado -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# python-fastjsonschema -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# pillow -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# yarl -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# widgetsnbextension -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# send2trash -> python -> bzip2[version='>=1.0.8,<2.0a0']
# numpy -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# ipython_genutils -> python -> bzip2[version='>=1.0.8,<2.0a0']
# nbformat -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# beautifulsoup4 -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# pyqt5-sip -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# aiosignal -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# idna -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# multidict -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# nbconvert -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# pcre2 -> bzip2[version='>=1.0.8,<2.0a0']
# git -> pcre2[version='>=10.37,<10.38.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# sip -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# jupyterlmod -> python -> bzip2[version='>=1.0.8,<2.0a0']
# parso -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# pycparser -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# stack_data -> python[version='>=3.5'] -> bzip2[version='>=1.0.8,<2.0a0']
# tqdm -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# pexpect -> python -> bzip2[version='>=1.0.8,<2.0a0']
# pyrsistent -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# matplotlib -> python[version='>=3.11,<3.12.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
#
# Package tzdata conflicts for:
# munkres -> python -> tzdata
# mistune -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# anyio -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# urllib3 -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# tinycss2 -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# python_abi -> python=3.10 -> tzdata
# jupyter_server -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# beautifulsoup4 -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# pyyaml -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# pygments -> python[version='>=3.5'] -> tzdata
# sniffio -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# jupyterlab_server -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# executing -> python[version='>=2.7'] -> tzdata
# asttokens -> python[version='>=3.5'] -> tzdata
# packaging -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# gitdb -> python[version='>=3.4'] -> tzdata
# requests -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# prometheus_client -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# pyrsistent -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# jedi -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# prompt-toolkit -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# ipykernel -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# backcall -> python -> tzdata
# setuptools -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# tomli -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# pytz -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# certifi -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# nbformat -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# cryptography -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# notebook-shim -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# entrypoints -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# six -> python -> tzdata
# python-fastjsonschema -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# argon2-cffi-bindings -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# pandocfilters -> python[version='!=3.0,!=3.1,!=3.2,!=3.3'] -> tzdata
# yarl -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# aiosignal -> python[version='>=3.6'] -> tzdata
# pip -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# brotlipy -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# pyqt5-sip -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# pyopenssl -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# pickleshare -> python[version='>=3'] -> tzdata
# typing_extensions -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# jupyterlab -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# platformdirs -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# parso -> python[version='>=3.6'] -> tzdata
# stack_data -> python[version='>=3.5'] -> tzdata
# tqdm -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# pexpect -> python -> tzdata
# frozenlist -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# pyqt -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# idna -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# jupyter_bokeh -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# kiwisolver -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# mkl_fft -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# pyzmq -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# argon2-cffi -> python[version='>=3.6'] -> tzdata
# sip -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# jupyterlmod -> python -> tzdata
# aiohttp -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# ipython_genutils -> python -> tzdata
# smmap -> python -> tzdata
# pycparser -> python[version='>=3.6'] -> tzdata
# python=3.10 -> tzdata
# matplotlib-base -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# traitlets -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# matplotlib -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# websocket-client -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# terminado -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# widgetsnbextension -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# send2trash -> python -> tzdata
# jupyter-server-mathjax -> python[version='>=3.7'] -> tzdata
# numpy -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# cycler -> python[version='>=3.6'] -> tzdata
# ply -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# notebook -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# attrs -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# gitpython -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# pyparsing -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# lxml -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# mkl_random -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# multidict -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# nbconvert -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# cffi -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# wheel -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# defusedxml -> python -> tzdata
# flit-core -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# nbclient -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# toml -> python[version='>=2.7'] -> tzdata
# jupyter-server-proxy -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# webencodings -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# pure_eval -> python[version='>=3.5'] -> tzdata
# json5 -> python -> tzdata
# wcwidth -> python -> tzdata
# ptyprocess -> python -> tzdata
# jupyterlab-git -> python[version='>=3.6,<4.0'] -> tzdata
# fonttools -> python[version='>=3.6'] -> tzdata
# async-timeout -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# pysocks -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# nbclassic -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# decorator -> python[version='>=3.5'] -> tzdata
# jsonschema -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# jupyter-vscode-proxy -> python[version='>=3'] -> tzdata
# ipyparallel -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# jupyter_core -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# pillow -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# babel -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# jupyter_client -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# bokeh -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# nest-asyncio -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# jupyterlab_widgets -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# contourpy -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# nbdime -> python[version='>=3.6'] -> tzdata
# simpervisor -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# matplotlib-inline -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# comm -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# markupsafe -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# jinja2 -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# bleach -> python[version='>=3.6'] -> tzdata
# ipython -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# jupyterlab_pygments -> python -> tzdata
# debugpy -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# numpy-base -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# psutil -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# ipywidgets -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# mkl-service -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# charset-normalizer -> python[version='>=3.5'] -> tzdata
# colorama -> python[version='>=3.11,<3.12.0a0'] -> tzdata
# soupsieve -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# typing-extensions -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# python-dateutil -> python -> tzdata
#
# Package openssl conflicts for:
# pure_eval -> python[version='>=3.5'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1m,<1.1.2a|>=1.1.1n,<1.1.2a|>=1.1.1q,<1.1.2a|>=1.1.1s,<1.1.2a|>=1.1.1t,<1.1.2a|>=1.1.1o,<1.1.2a|>=1.0.2l,<1.0.3a']
# json5 -> python -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1m,<1.1.2a|>=1.1.1n,<1.1.2a|>=1.1.1q,<1.1.2a|>=1.1.1s,<1.1.2a|>=1.1.1t,<1.1.2a|>=1.1.1o,<1.1.2a|>=1.0.2l,<1.0.3a']
# ptyprocess -> python -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1m,<1.1.2a|>=1.1.1n,<1.1.2a|>=1.1.1q,<1.1.2a|>=1.1.1s,<1.1.2a|>=1.1.1t,<1.1.2a|>=1.1.1o,<1.1.2a|>=1.0.2l,<1.0.3a']
# munkres -> python -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1m,<1.1.2a|>=1.1.1n,<1.1.2a|>=1.1.1q,<1.1.2a|>=1.1.1s,<1.1.2a|>=1.1.1t,<1.1.2a|>=1.1.1o,<1.1.2a|>=1.0.2l,<1.0.3a']
# python_abi -> python=3.10 -> openssl[version='>=1.1.1l,<1.1.2a|>=1.1.1m,<1.1.2a|>=1.1.1n,<1.1.2a|>=1.1.1q,<1.1.2a|>=1.1.1s,<1.1.2a|>=1.1.1t,<1.1.2a']
# fonttools -> python[version='>=3.6'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1m,<1.1.2a|>=1.1.1n,<1.1.2a|>=1.1.1q,<1.1.2a|>=1.1.1s,<1.1.2a|>=1.1.1t,<1.1.2a|>=1.1.1o,<1.1.2a|>=1.0.2l,<1.0.3a']
# matplotlib-base -> python[version='>=3.11,<3.12.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1n,<1.1.2a|>=1.1.1q,<1.1.2a|>=1.1.1s,<1.1.2a|>=1.1.1t,<1.1.2a|>=1.1.1o,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1m,<1.1.2a|>=1.0.2l,<1.0.3a']
# python=3.10 -> openssl[version='>=1.1.1l,<1.1.2a|>=1.1.1m,<1.1.2a|>=1.1.1n,<1.1.2a|>=1.1.1q,<1.1.2a|>=1.1.1s,<1.1.2a|>=1.1.1t,<1.1.2a']
# cycler -> python[version='>=3.6'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1m,<1.1.2a|>=1.1.1n,<1.1.2a|>=1.1.1q,<1.1.2a|>=1.1.1s,<1.1.2a|>=1.1.1t,<1.1.2a|>=1.1.1o,<1.1.2a|>=1.0.2l,<1.0.3a']
# libcurl -> libnghttp2[version='>=1.41.0,<2.0a0'] -> openssl[version='>=1.0.2m,<1.0.3a|>=1.1.1h,<1.1.2a|>=1.1.1j,<1.1.2a']
# decorator -> python[version='>=3.5'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1m,<1.1.2a|>=1.1.1n,<1.1.2a|>=1.1.1q,<1.1.2a|>=1.1.1s,<1.1.2a|>=1.1.1t,<1.1.2a|>=1.1.1o,<1.1.2a|>=1.0.2l,<1.0.3a']
# notebook-shim -> python[version='>=3.11,<3.12.0a0'] -> openssl[version='>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1n,<1.1.2a|>=1.1.1q,<1.1.2a|>=1.1.1s,<1.1.2a|>=1.1.1t,<1.1.2a|>=1.1.1m,<1.1.2a|>=1.1.1o,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a']
# jupyter-vscode-proxy -> python[version='>=3'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1m,<1.1.2a|>=1.1.1n,<1.1.2a|>=1.1.1q,<1.1.2a|>=1.1.1s,<1.1.2a|>=1.1.1t,<1.1.2a|>=1.1.1o,<1.1.2a|>=1.0.2l,<1.0.3a']
# typing_extensions -> python[version='>=3.9,<3.10.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1n,<1.1.2a|>=1.1.1o,<1.1.2a|>=1.1.1q,<1.1.2a|>=1.1.1s,<1.1.2a|>=1.1.1t,<1.1.2a|>=1.1.1m,<1.1.2a|>=1.0.2l,<1.0.3a']
# platformdirs -> python[version='>=3.11,<3.12.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1n,<1.1.2a|>=1.1.1o,<1.1.2a|>=1.1.1q,<1.1.2a|>=1.1.1s,<1.1.2a|>=1.1.1t,<1.1.2a|>=1.1.1m,<1.1.2a|>=1.0.2l,<1.0.3a']
# libnghttp2 -> openssl[version='>=1.1.1h,<1.1.2a|>=1.1.1l,<1.1.2a']
# python-fastjsonschema -> python[version='>=3.11,<3.12.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1n,<1.1.2a|>=1.1.1q,<1.1.2a|>=1.1.1s,<1.1.2a|>=1.1.1t,<1.1.2a|>=1.1.1m,<1.1.2a|>=1.1.1o,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.0.2l,<1.0.3a']
# pyqt5-sip -> python[version='>=3.9,<3.10.0a0'] -> openssl[version='>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1n,<1.1.2a|>=1.1.1o,<1.1.2a|>=1.1.1q,<1.1.2a|>=1.1.1s,<1.1.2a|>=1.1.1t,<1.1.2a|>=1.1.1m,<1.1.2a']
# pillow -> python[version='>=3.11,<3.12.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1n,<1.1.2a|>=1.1.1q,<1.1.2a|>=1.1.1s,<1.1.2a|>=1.1.1t,<1.1.2a|>=1.1.1m,<1.1.2a|>=1.1.1o,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.0.2l,<1.0.3a']
# notebook -> python[version='>=3.9,<3.10.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1n,<1.1.2a|>=1.1.1o,<1.1.2a|>=1.1.1q,<1.1.2a|>=1.1.1s,<1.1.2a|>=1.1.1t,<1.1.2a|>=1.1.1m,<1.1.2a|>=1.0.2l,<1.0.3a']
# mistune -> python[version='>=3.11,<3.12.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1m,<1.1.2a|>=1.1.1n,<1.1.2a|>=1.1.1q,<1.1.2a|>=1.1.1s,<1.1.2a|>=1.1.1t,<1.1.2a|>=1.1.1o,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.0.2l,<1.0.3a']
# qt-main -> krb5[version='>=1.19.4,<1.20.0a0'] -> openssl[version='>=1.1.1l,<1.1.2a|>=1.1.1m,<1.1.2a|>=1.1.1s,<1.1.2a|>=1.1.1o,<1.1.2a']
# ...
# nbformat -> jsonschema[version='>=2.6'] -> pkgutil-resolve-name[version='>=1.3.10']
# jupyterlab_server -> jsonschema[version='>=4.17.3'] -> pkgutil-resolve-name[version='>=1.3.10']
#
# Package libbrotlienc conflicts for:
# fonttools -> brotli[version='>=1.0.1'] -> libbrotlienc==1.0.9=h5eee18b_7
# brotli -> libbrotlienc==1.0.9=h5eee18b_7
# brotli-bin -> libbrotlienc==1.0.9=h5eee18b_7
#
# Package twisted conflicts for:
# jupyter_server -> prometheus_client -> twisted
# nbclassic -> prometheus_client -> twisted
# notebook -> prometheus_client -> twisted
# prometheus_client -> twisted
#
# Package subprocess32 conflicts for:
# matplotlib -> subprocess32
# jupyterlab -> subprocess32
# bokeh -> matplotlib -> subprocess32
#
# Package pympler conflicts for:
# aiohttp -> attrs[version='>=17.3.0'] -> pympler
# attrs -> pympler
#
# Package lcms2 conflicts for:
# graphviz -> poppler -> lcms2[version='>=2.12,<3.0a0']
# texlive-core -> poppler -> lcms2[version='>=2.12,<3.0a0']
# pillow -> lcms2[version='>=2.11,<3.0a0|>=2.12,<3.0a0']
# poppler -> lcms2[version='>=2.12,<3.0a0']
# bokeh -> pillow[version='>=7.1.0'] -> lcms2[version='>=2.11,<3.0a0|>=2.12,<3.0a0']
# matplotlib-base -> pillow[version='>=6.2.0'] -> lcms2[version='>=2.11,<3.0a0|>=2.12,<3.0a0']
#
# Package contourpy conflicts for:
# matplotlib -> matplotlib-base[version='>=3.7.1,<3.7.2.0a0'] -> contourpy[version='>=1.0.1']
# matplotlib-base -> contourpy[version='>=1.0.1']
# bokeh -> contourpy[version='>=1']
# jupyter_bokeh -> bokeh[version='>=3,<4'] -> contourpy[version='>=1']
#
# Package qt-webengine conflicts for:
# pyqt -> qt-webengine[version='5.15.*|>=5.15.9,<5.16.0a0']
# matplotlib -> pyqt[version='>=5'] -> qt-webengine[version='5.15.*|>=5.15.9,<5.16.0a0']
# qtwebkit -> qt-webengine[version='>=5.15.9,<5.16.0a0']
#
# Package matplotlib-base conflicts for:
# matplotlib -> matplotlib-base[version='3.1.2|3.1.2|3.1.2|3.1.3|3.1.3|3.1.3|>=3.2.1,<3.2.2.0a0|>=3.2.2,<3.2.3.0a0|>=3.3.1,<3.3.2.0a0|>=3.3.2,<3.3.3.0a0|>=3.3.4,<3.3.5.0a0|>=3.4.2,<3.4.3.0a0|>=3.4.3,<3.4.4.0a0|>=3.5.0,<3.5.1.0a0|>=3.5.1,<3.5.2.0a0|>=3.5.2,<3.5.3.0a0|>=3.5.3,<3.5.4.0a0|>=3.6.2,<3.6.3.0a0|>=3.7.0,<3.7.1.0a0|>=3.7.1,<3.7.2.0a0',build='py38hef1b27d_1|py36hef1b27d_0|py37hef1b27d_0|py38hef1b27d_0|py36hef1b27d_1|py37hef1b27d_1']
# bokeh -> matplotlib -> matplotlib-base[version='3.1.2|3.1.2|3.1.2|3.1.3|3.1.3|3.1.3|>=3.2.1,<3.2.2.0a0|>=3.2.2,<3.2.3.0a0|>=3.3.1,<3.3.2.0a0|>=3.3.2,<3.3.3.0a0|>=3.3.4,<3.3.5.0a0|>=3.4.2,<3.4.3.0a0|>=3.4.3,<3.4.4.0a0|>=3.5.0,<3.5.1.0a0|>=3.5.1,<3.5.2.0a0|>=3.5.2,<3.5.3.0a0|>=3.5.3,<3.5.4.0a0|>=3.6.2,<3.6.3.0a0|>=3.7.0,<3.7.1.0a0|>=3.7.1,<3.7.2.0a0',build='py38hef1b27d_1|py36hef1b27d_0|py37hef1b27d_0|py38hef1b27d_0|py36hef1b27d_1|py37hef1b27d_1']
#
# Package aiosignal conflicts for:
# jupyter-server-proxy -> aiohttp -> aiosignal[version='>=1.1.2']
# aiohttp -> aiosignal[version='>=1.1.2']
#
# Package c-ares conflicts for:
# libcurl -> libnghttp2[version='>=1.46.0'] -> c-ares[version='>=1.16.1,<2.0a0|>=1.17.1,<2.0a0|>=1.7.5']
# libnghttp2 -> c-ares[version='>=1.16.1,<2.0a0|>=1.17.1,<2.0a0|>=1.7.5']
#
# Package qt conflicts for:
# pyqt -> qt[version='5.6.*|5.9.*|>=5.9.7,<5.10.0a0|>=5.9.6,<5.10.0a0|>=5.9.4,<5.10.0a0|>=5.6.3,<5.7.0a0']
# matplotlib -> pyqt[version='>=5'] -> qt[version='5.6.*|5.9.*|>=5.9.7,<5.10.0a0|>=5.9.6,<5.10.0a0|>=5.9.4,<5.10.0a0|>=5.6.3,<5.7.0a0']
#
# Package urllib3 conflicts for:
# nbdime -> requests -> urllib3[version='>=1.21.1,<1.23|>=1.21.1,<1.24|>=1.21.1,<1.25|>=1.21.1,<1.26,!=1.25.0,!=1.25.1|>=1.21.1,<1.27']
# requests -> urllib3[version='>=1.21.1,<1.23|>=1.21.1,<1.24|>=1.21.1,<1.25|>=1.21.1,<1.26,!=1.25.0,!=1.25.1|>=1.21.1,<1.27']
# jupyterlab_server -> requests[version='>=2.28'] -> urllib3[version='>=1.21.1,<1.23|>=1.21.1,<1.24|>=1.21.1,<1.25|>=1.21.1,<1.26,!=1.25.0,!=1.25.1|>=1.21.1,<1.27']
# bokeh -> requests[version='>=1.2.3'] -> urllib3[version='>=1.21.1,<1.23|>=1.21.1,<1.24|>=1.21.1,<1.25|>=1.21.1,<1.26,!=1.25.0,!=1.25.1|>=1.21.1,<1.27']
#
# Package lxml conflicts for:
# notebook -> nbconvert[version='>=5'] -> lxml
# jupyter_server -> nbconvert[version='>=6.4.4'] -> lxml
# nbclassic -> nbconvert[version='>=5'] -> lxml
# nbconvert -> lxml
#
# Package requests conflicts for:
# jupyterlab-git -> nbdime[version='>=3.1,<4.0'] -> requests
# bokeh -> requests[version='>=1.2.3']
# jupyterlab -> jupyterlab_server[version='>=2.10,<3'] -> requests[version='>=2.28']
# nbdime -> requests
# jupyterlab_server -> requests[version='>=2.28']
#
# Package poppler-data conflicts for:
# poppler -> poppler-data[version='>=0.4.8|>=0.4.9']
# texlive-core -> poppler[version='>=0.65.0,<1.0a0'] -> poppler-data[version='>=0.4.8|>=0.4.9']
# graphviz -> poppler -> poppler-data[version='>=0.4.8|>=0.4.9']
#
# Package wheel conflicts for:
# pip -> wheel
# python=3.10 -> pip -> wheel
#
# Package ply conflicts for:
# pyqt5-sip -> sip -> ply
# sip -> ply
# pyqt -> sip[version='>=6.6.2,<6.7.0a0'] -> ply
#
# Package jupyterlab_widgets conflicts for:
# ipywidgets -> jupyterlab_widgets[version='>=1.0.0|>=3.0.4,<4.0.0']
# jupyter_bokeh -> ipywidgets[version='>=8,<9'] -> jupyterlab_widgets[version='>=1.0.0|>=3.0.4,<4.0.0']
#
# Package idna_ssl conflicts for:
# aiohttp -> idna_ssl[version='>=1,<2|>=1.0']
# jupyter-server-proxy -> aiohttp -> idna_ssl[version='>=1,<2|>=1.0']
#
# Package numpydoc conflicts for:
# jedi -> numpydoc
# ipython -> jedi[version='>=0.10,<0.18'] -> numpydoc
#
# Package pyyaml conflicts for:
# bokeh -> pyyaml[version='>=3.10']
# jupyter_bokeh -> bokeh[version='>=3,<4'] -> pyyaml[version='>=3.10']
#
# Package aiohttp conflicts for:
# jupyter-server-proxy -> aiohttp
# jupyter-vscode-proxy -> jupyter-server-proxy -> aiohttp
#
# Package colorama conflicts for:
# jupyterlab-git -> nbdime[version='>=3.1,<4.0'] -> colorama
# nbdime -> colorama
# ipyparallel -> tqdm -> colorama
# tqdm -> colorama
#
# Package giflib conflicts for:
# qtwebkit -> libwebp -> giflib[version='>=5.1.4,<5.2.0a0|>=5.2.1,<5.3.0a0']
# graphviz -> libwebp -> giflib[version='>=5.1.4,<5.2.0a0|>=5.2.1,<5.3.0a0']
# libwebp -> giflib[version='>=5.1.4,<5.2.0a0|>=5.2.1,<5.3.0a0']
# pillow -> libwebp[version='>=1.2.0,<1.3.0a0'] -> giflib[version='>=5.1.4,<5.2.0a0|>=5.2.1,<5.3.0a0']
#
# Package simpervisor conflicts for:
# jupyter-vscode-proxy -> jupyter-server-proxy -> simpervisor[version='>=0.4']
# jupyter-server-proxy -> simpervisor[version='>=0.4']
#
# Package libgfortran4 conflicts for:
# numpy -> libopenblas[version='>=0.3.3,<1.0a0'] -> libgfortran4[version='7.5.0.*|>=7.5.0']
# numpy-base -> libopenblas[version='>=0.3.3,<1.0a0'] -> libgfortran4[version='7.5.0.*|>=7.5.0']
#
# Package tomli conflicts for:
# jupyterlab -> tomli
# jupyterlmod -> jupyterlab[version='>=2'] -> tomli
#
# Package scandir conflicts for:
# ipython -> pathlib2 -> scandir
# pickleshare -> pathlib2 -> scandir
#
# Package jupyter-server-mathjax conflicts for:
# nbdime -> jupyter-server-mathjax[version='>=0.2.2']
# jupyterlab-git -> nbdime[version='>=3.1,<4.0'] -> jupyter-server-mathjax[version='>=0.2.2']
#
# Package libpq conflicts for:
# qt-main -> libpq[version='>=12.9,<13.0a0']
# qt-webengine -> qt-main[version='>=5.15,<6.0a0'] -> libpq[version='>=12.9,<13.0a0']
# qtwebkit -> qt-main[version='>=5.15.2,<5.16.0a0'] -> libpq[version='>=12.9,<13.0a0']
# pyqt -> qt-main=5.15 -> libpq[version='>=12.9,<13.0a0']
#
# Package yaml conflicts for:
# bokeh -> pyyaml[version='>=3.10'] -> yaml[version='>=0.1.7,<0.2.0a0|>=0.2.5,<0.3.0a0']
# pyyaml -> yaml[version='>=0.1.7,<0.2.0a0|>=0.2.5,<0.3.0a0']
#
# Package pure_eval conflicts for:
# ipython -> stack_data -> pure_eval
# stack_data -> pure_eval
#
# Package fonttools conflicts for:
# matplotlib -> matplotlib-base[version='>=3.7.1,<3.7.2.0a0'] -> fonttools[version='>=4.22.0']
# matplotlib-base -> fonttools[version='>=4.22.0']The following specifications were found to be incompatible with your system:
#
#   - feature:/linux-64::__glibc==2.17=0
#   - feature:|@/linux-64::__glibc==2.17=0
#   - aiohttp -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - argon2-cffi -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - argon2-cffi-bindings -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - brotli -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - brotli-bin -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - brotlipy -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - bzip2 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - c-ares -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - cairo -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - cffi -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - contourpy -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - cryptography -> libgcc-ng -> __glibc[version='>=2.17']
#   - curl -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - dbus -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - debugpy -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - expat -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - fontconfig -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - freetype -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - frozenlist -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - gdbm -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - gettext -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - giflib -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - git -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - glib -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - gmp -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - graphite2 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - graphviz -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - gst-plugins-base -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - gstreamer -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - harfbuzz -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - icu -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - intel-openmp -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - jpeg -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - jupyter_bokeh -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - kiwisolver -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - krb5 -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - lcms2 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - lerc -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libbrotlicommon -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - libbrotlidec -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - libbrotlienc -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - libclang -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - libcurl -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - libdeflate -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - libedit -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - libev -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libevent -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libffi -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - libgcc-ng -> __glibc[version='>=2.17']
#   - libllvm10 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libnghttp2 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libpng -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - libpq -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - libsodium -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libssh2 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libstdcxx-ng -> __glibc[version='>=2.17']
#   - libtiff -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - libuuid -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - libwebp -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - libwebp-base -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - libxcb -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libxkbcommon -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - libxml2 -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - libxslt -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - lxml -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - lz4-c -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - markupsafe -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - matplotlib -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - matplotlib-base -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - mistune -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - mkl -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - mkl-service -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - mkl_fft -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - mkl_random -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - mpfr -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - multidict -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - ncurses -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - nspr -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - nss -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - numpy -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - numpy-base -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - openjpeg -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - openssl -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - pcre -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - pcre2 -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - perl -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - pillow -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - pixman -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - poppler -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - psutil -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - pyqt -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17|>=2.17,<3.0.a0']
#   - pyqt5-sip -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - pyrsistent -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - python=3.10 -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - pyyaml -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - pyzmq -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - qt-main -> __glibc[version='>=2.17,<3.0.a0']
#   - qt-main -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - qt-webengine -> __glibc[version='>=2.17,<3.0.a0']
#   - qt-webengine -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - qtwebkit -> __glibc[version='>=2.17,<3.0.a0']
#   - qtwebkit -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - readline -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - sip -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - sqlite -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - texlive-core -> libgcc-ng[version='>=7.2.0'] -> __glibc[version='>=2.17']
#   - tk -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - xz -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - yaml -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - yarl -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - zeromq -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - zlib -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - zstd -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#
# Your installed version is: 2.17
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sklearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sklearn in ./.local/lib/python3.10/site-packages (0.0.post1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Downloading scikit_learn-1.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 484.8 kB/s eta 0:00:0000:0100:02
# Collecting scipy>=1.3.2
#   Downloading scipy-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 1.1 MB/s eta 0:00:00:00:0100:01
# Collecting joblib>=1.1.1
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 2.3 MB/s eta 0:00:0000:0100:01
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy>=1.17.3 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from scikit-learn) (1.23.5)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.2.0 scikit-learn-1.2.2 scipy-1.10.1 threadpoolctl-3.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import sklearn
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
pip install pathlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pathlib
#   Downloading pathlib-1.0.1-py3-none-any.whl (14 kB)
# Installing collected packages: pathlib
# Successfully installed pathlib-1.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install math
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement math (from versions: none)
# ERROR: No matching distribution found for math
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install torch

# %%
pip install datetime
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting datetime
#   Downloading DateTime-5.1-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 690.5 kB/s eta 0:00:00 0:00:01
# Collecting zope.interface
#   Downloading zope.interface-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (246 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 2.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pytz in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from datetime) (2022.7)
# Requirement already satisfied: setuptools in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from zope.interface->datetime) (65.6.3)
# Installing collected packages: zope.interface, datetime
# Successfully installed datetime-5.1 zope.interface-6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Downloading pandas-1.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 2.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pytz>=2020.1 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from pandas) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pandas
# Successfully installed pandas-1.5.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (3.6.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: numpy>=1.19 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.7 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from matplotlib) (22.0)
# Requirement already satisfied: cycler>=0.10 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: six>=1.5 in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /gstore/apps/jupyterlab/3.5.2-Python-3.10/lib/python3.10/site-packages (1.23.5)
# Note: you may need to restart the kernel to use updated packages.
